# %%
import pandas as pd
import numpy as np
import import_ipynb
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %%
sns.scatterplot(x='Happiness Score',y='Economy (GDP per Capita)', data=df, hue='Region', palette='bright')
plt.legend(fontsize='6')

# %%
sns.scatterplot(x='Happiness Score',y='Family', data=df, hue='Region', palette='bright')
plt.legend(fontsize='6')

# %%
sns.scatterplot(x='Happiness Score',y='Health (Life Expectancy)', data=df, hue='Region', palette='bright')
plt.legend(fontsize='6')

# %% [markdown]
# .

# %%
df['Country'].nunique()
# Out:
# 158

# %%
df['Region'].nunique()
# Out:
# 10

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df['Region_code'] = pd.factorize(df.Region)[0]
df['Region_code']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 153    8
# 154    8
# 155    3
# 156    8
# 157    8
# Name: Region_code, Length: 158, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
df['Region_code'].value_counts()
# Out:
# 8    40
# 6    29
# 4    22
# 0    21
# 3    20
# 5     9
# 9     7
# 7     6
# 1     2
# 2     2
# Name: Region_code, dtype: int64

# %%
del df['Region']

# %% [markdown]
# .

# %% [markdown]
# .

# %%
df
# Out:
#          Country  Happiness Rank  Happiness Score  Standard Error  \
# 0    Switzerland               1            7.587         0.03411
# 1        Iceland               2            7.561         0.04884
# 2        Denmark               3            7.527         0.03328
# 3         Norway               4            7.522         0.03880
# 4         Canada               5            7.427         0.03553
# ..           ...             ...              ...             ...
# 153       Rwanda             154            3.465         0.03464
# 154        Benin             155            3.340         0.03656
# 155        Syria             156            3.006         0.05015
# 156      Burundi             157            2.905         0.08658
# 157         Togo             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...

# %%
df1 = df.iloc[:,2:]

# %%
correlation = df1.corr()
sns.heatmap(correlation, fmt='.1g', linecolor = 'red', annot=True)
# Out:
# <Axes: >

# %%
sns.displot(data=df1, x='Happiness Score')

# %%
sns.scatterplot(x='Standard Error',y='Happiness Score',data=df1)
# Out:
# <Axes: xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df1)
# Out:
# <Axes: xlabel='Generosity', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df1)
# Out:
# <Axes: xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %% [markdown]
# .

# %% [markdown]
# .

# %%
sns.boxplot(df['Standard Error'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Trust (Government Corruption)'])
# Out:
# <Axes: >

# %%
sns.boxplot(df1['Happiness Score'])
# Out:
# <Axes: >

# %%
sns.boxplot(df1['Economy (GDP per Capita)'])
# Out:
# <Axes: >

# %%
sns.boxplot(df1['Generosity'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Family'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Health (Life Expectancy)'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Freedom'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Dystopia Residual'])
# Out:
# <Axes: >

# %% [markdown]
# # outliers are present in Standard Error and Trust (Government Corruption)

# %% [raw]
# del df1['Standard Error']

# %%
q1 = df1['Trust (Government Corruption)'].quantile(.25)
q3 = df1['Trust (Government Corruption)'].quantile(.75)

iqr = q3-q1
low = q1-1.5*iqr
up = q3+1.5*iqr

print(low)
print(up)
# Out:
# -0.11619499999999996
# 0.35812499999999997

# %%
new_df = df1.loc[(df1['Trust (Government Corruption)']<up) & (df1['Trust (Government Corruption)']>low)]
print(len(df1))
print(len(new_df))
# Out:
# 158
# 144

# %%
q1 = new_df['Standard Error'].quantile(.25)
q3 = new_df['Standard Error'].quantile(.75)

iqr = q3-q1
low = q1-1.5*iqr
up = q3+1.5*iqr

print(low)
print(up)
# Out:
# 0.01595625000000001
# 0.07458624999999999

# %%
new_df2 = new_df.loc[(new_df['Standard Error']<up) & (new_df['Standard Error']>low)]
print(len(new_df))
print(len(new_df2))
# Out:
# 144
# 134

# %% [markdown]
# .

# %%
df1.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# Region_code                     -0.477295
# dtype: float64

# %%
new_df.skew()
# Out:
# Happiness Score                  0.095327
# Standard Error                   1.943992
# Economy (GDP per Capita)        -0.382097
# Family                          -1.005398
# Health (Life Expectancy)        -0.687742
# Freedom                         -0.396039
# Trust (Government Corruption)    1.046761
# Generosity                       1.177371
# Dystopia Residual               -0.093945
# Region_code                     -0.537709
# dtype: float64

# %%
new_df2.skew()
# Out:
# Happiness Score                  0.129496
# Standard Error                   0.488702
# Economy (GDP per Capita)        -0.383642
# Family                          -1.012357
# Health (Life Expectancy)        -0.739617
# Freedom                         -0.408165
# Trust (Government Corruption)    1.053720
# Generosity                       1.116993
# Dystopia Residual               -0.044613
# Region_code                     -0.519527
# dtype: float64

# %%
new_df2
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 1              7.561         0.04884                   1.30232  1.40223
# 4              7.427         0.03553                   1.32629  1.32261
# 6              7.378         0.02799                   1.32944  1.28017
# 9              7.284         0.04083                   1.33358  1.30923
# 10             7.278         0.03470                   1.22857  1.22393
# ..               ...             ...                       ...      ...
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %%
sns.heatmap(new_df2.corr(), fmt='.1g', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = new_df2.drop('Happiness Score', axis=1)
y = new_df2['Happiness Score']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=42)
print(x_train.shape)
print(x_test.shape)
# Out:
# (93, 9)
# (41, 9)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
svm = SVR()
svm.fit(x_train,y_train)
# Out:
# SVR()

# %%
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
rfr= RandomForestRegressor()
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
gbr= GradientBoostingRegressor()
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred1 = svm.predict(x_test)
y_pred2 = lr.predict(x_test)
y_pred3 = rfr.predict(x_test)
y_pred4 = gbr.predict(x_test)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
svm1 = metrics.r2_score(y_test,y_pred1)
svm1
# Out:
# 0.8444000105147861

# %%
lr2 = metrics.r2_score(y_test,y_pred2)
lr2
# Out:
# 0.9999999212820121

# %%
rfr3 = metrics.r2_score(y_test,y_pred3)
rfr3
# Out:
# 0.9062692196203415

# %%
gbr4 = metrics.r2_score(y_test,y_pred4)
gbr4
# Out:
# 0.9233910976521631

# %% [markdown]
# # LinearRegression is best

# %% [markdown]
# .

# %%
from sklearn.model_selection import cross_val_score

# %%
recheck = cross_val_score(svm,x,y)
print(recheck)
print(recheck.mean())
# Out:
# [-7.81343439 -4.51801384 -2.48094301 -6.96081762 -2.21538537]
# -4.797718847023298

# %%
recheck = cross_val_score(lr,x,y)
print(recheck)
print(recheck.mean())
# Out:
# [0.99999949 0.99999688 0.99999745 0.99999503 0.99999934]
# 0.9999976382788305

# %%
recheck = cross_val_score(rfr,x,y)
print(recheck)
print(recheck.mean())
# Out:
# [-6.65673862 -3.63800332 -2.17285658 -3.40277406 -5.87924524]
# -4.349923565080534

# %%
recheck = cross_val_score(gbr,x,y)
print(recheck)
print(recheck.mean())
# Out:
# [-3.71962752 -5.63427877 -1.97063847 -4.7260232  -4.25377333]
# -4.060868258329079

# %% [markdown]
# # LinearRegression is best even after retesting
