# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('termdeposit_train.csv')
df
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
del df['ID']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         31647 non-null  int64
#  1   job         31647 non-null  object
#  2   marital     31647 non-null  object
#  3   education   31647 non-null  object
#  4   default     31647 non-null  object
#  5   balance     31647 non-null  int64
#  6   housing     31647 non-null  object
#  7   loan        31647 non-null  object
#  8   contact     31647 non-null  object
#  9   day         31647 non-null  int64
#  10  month       31647 non-null  object
#  11  duration    31647 non-null  int64
#  12  campaign    31647 non-null  int64
#  13  pdays       31647 non-null  int64
#  14  previous    31647 non-null  int64
#  15  poutcome    31647 non-null  object
#  16  subscribed  31647 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 4.1+ MB

# %%
df['job'].nunique()
# Out:
# 12

# %%
df['job'].value_counts()
# Out:
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: job, dtype: int64

# %%
df['job'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='job'>

# %%
df.nunique()
# Out:
# age             76
# job             12
# marital          3
# education        4
# default          2
# balance       6326
# housing          2
# loan             2
# contact          3
# day             31
# month           12
# duration      1454
# campaign        45
# pdays          509
# previous        38
# poutcome         4
# subscribed       2
# dtype: int64

# %% [markdown]
# .

# %%
df['age'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='age'>

# %%
sns.countplot(x='age', data=df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
sns.displot(x='age', data=df)

# %%
df['marital'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='marital'>

# %%
df['education'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='education'>

# %%
df['default'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='default'>

# %%
df['housing'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='housing'>

# %%
df['loan'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='loan'>

# %%
df['contact'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='contact'>

# %%
df['day'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='day'>

# %%
sns.displot(x='day',data=df)

# %%
df['month'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='month'>

# %%
sns.displot(x='month',data=df)

# %%
df['campaign'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='campaign'>

# %%
sns.displot(x='campaign',data=df)

# %%
df['previous'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='previous'>

# %%
sns.displot(x='previous',data=df)

# %%
df['poutcome'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='poutcome'>

# %%
df['subscribed'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='subscribed'>

# %% [markdown]
# ## Data is very unbalanced

# %%
df['job'].value_counts()
# Out:
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: job, dtype: int64

# %%
df['job']= pd.factorize(df['job'])[0]

# %%
df['job'].value_counts()
# Out:
# 6     6842
# 3     6639
# 4     5307
# 0     3631
# 2     2903
# 5     1574
# 8     1123
# 10    1008
# 11     905
# 7      874
# 9      635
# 1      206
# Name: job, dtype: int64

# %% [markdown]
# .

# %%
df['marital'].value_counts()
# Out:
# married     19095
# single       8922
# divorced     3630
# Name: marital, dtype: int64

# %%
df['marital']= pd.factorize(df['marital'])[0]

# %%
df['marital'].value_counts()
# Out:
# 0    19095
# 2     8922
# 1     3630
# Name: marital, dtype: int64

# %% [markdown]
# .

# %%
df['education'].value_counts()
# Out:
# secondary    16224
# tertiary      9301
# primary       4808
# unknown       1314
# Name: education, dtype: int64

# %%
df['education']= pd.factorize(df['education'])[0]

# %%
df['education'].value_counts()
# Out:
# 1    16224
# 2     9301
# 3     4808
# 0     1314
# Name: education, dtype: int64

# %% [markdown]
# .

# %%
df['default'].value_counts()
# Out:
# no     31062
# yes      585
# Name: default, dtype: int64

# %%
df['default']= pd.factorize(df['default'])[0]

# %%
df['default'].value_counts()
# Out:
# 0    31062
# 1      585
# Name: default, dtype: int64

# %% [markdown]
# .

# %%
df['housing'].value_counts()
# Out:
# yes    17584
# no     14063
# Name: housing, dtype: int64

# %%
df['housing']= pd.factorize(df['housing'])[0]

# %%
df['housing'].value_counts()
# Out:
# 1    17584
# 0    14063
# Name: housing, dtype: int64

# %% [markdown]
# .

# %%
df['loan'].value_counts()
# Out:
# no     26516
# yes     5131
# Name: loan, dtype: int64

# %%
df['loan']= pd.factorize(df['loan'])[0]

# %%
df['loan'].value_counts()
# Out:
# 0    26516
# 1     5131
# Name: loan, dtype: int64

# %% [markdown]
# .

# %%
df['contact'].value_counts()
# Out:
# cellular     20423
# unknown       9177
# telephone     2047
# Name: contact, dtype: int64

# %%
df['contact']= pd.factorize(df['contact'])[0]

# %%
df['contact'].value_counts()
# Out:
# 1    20423
# 2     9177
# 0     2047
# Name: contact, dtype: int64

# %% [markdown]
# .

# %%
df['month'].value_counts()
# Out:
# may    9669
# jul    4844
# aug    4333
# jun    3738
# nov    2783
# apr    2055
# feb    1827
# jan     977
# oct     512
# sep     410
# mar     342
# dec     157
# Name: month, dtype: int64

# %%
df['month']= pd.factorize(df['month'])[0]

# %%
df['month'].value_counts()
# Out:
# 6     9669
# 1     4844
# 7     4333
# 2     3738
# 0     2783
# 8     2055
# 3     1827
# 5      977
# 9      512
# 4      410
# 10     342
# 11     157
# Name: month, dtype: int64

# %% [markdown]
# .

# %%
df['poutcome'].value_counts()
# Out:
# unknown    25929
# failure     3362
# other       1288
# success     1068
# Name: poutcome, dtype: int64

# %%
df['poutcome']= pd.factorize(df['poutcome'])[0]

# %%
df['poutcome'].value_counts()
# Out:
# 0    25929
# 2     3362
# 3     1288
# 1     1068
# Name: poutcome, dtype: int64

# %% [markdown]
# .

# %%
df['subscribed'].value_counts()
# Out:
# no     27932
# yes     3715
# Name: subscribed, dtype: int64

# %%
df['subscribed']= pd.factorize(df['subscribed'])[0]

# %%
df['subscribed'].value_counts()
# Out:
# 0    27932
# 1     3715
# Name: subscribed, dtype: int64

# %% [markdown]
# .

# %%
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       56    0        0          0        0     1933        0     0        0
# 1       31    1        0          1        0        3        0     0        1
# 2       27    2        0          1        0      891        1     0        1
# 3       57    3        1          2        0     3287        0     0        1
# 4       31    4        0          1        0      119        1     0        1
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 31642   29    3        2          2        0        0        1     0        1
# 31643   53    3        1          2        0      380        0     1        1
# 31644   32    3        2          2        0      312        0     0        1
# 31645   57    4        0          1        0      225        1     0        0
# 31646   55    3        1          1        0      204        1     0        1
#
# ...

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(), fmt='.1g', annot=True, annot_kws={'fontsize':15})
# Out:
# <Axes: >

# %%
aaa='duration,pdays,poutcome,previous,housing,contact'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         31647 non-null  int64
#  1   job         31647 non-null  int64
#  2   marital     31647 non-null  int64
#  3   education   31647 non-null  int64
#  4   default     31647 non-null  int64
#  5   balance     31647 non-null  int64
#  6   housing     31647 non-null  int64
#  7   loan        31647 non-null  int64
#  8   contact     31647 non-null  int64
#  9   day         31647 non-null  int64
#  10  month       31647 non-null  int64
#  11  duration    31647 non-null  int64
#  12  campaign    31647 non-null  int64
#  13  pdays       31647 non-null  int64
#  14  previous    31647 non-null  int64
#  15  poutcome    31647 non-null  int64
#  16  subscribed  31647 non-null  int64
# dtypes: int64(17)
# memory usage: 4.1 MB

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.iloc[:,5:6].plot(kind='box')
# Out:
# <Axes: >

# %%
x=df.drop('subscribed',axis=1)

# %%
y=df['subscribed']

# %%
x
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       56    0        0          0        0     1933        0     0        0
# 1       31    1        0          1        0        3        0     0        1
# 2       27    2        0          1        0      891        1     0        1
# 3       57    3        1          2        0     3287        0     0        1
# 4       31    4        0          1        0      119        1     0        1
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 31642   29    3        2          2        0        0        1     0        1
# 31643   53    3        1          2        0      380        0     1        1
# 31644   32    3        2          2        0      312        0     0        1
# 31645   57    4        0          1        0      225        1     0        0
# 31646   55    3        1          1        0      204        1     0        1
#
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 31642    0
# 31643    1
# 31644    0
# 31645    0
# 31646    1
# Name: subscribed, Length: 31647, dtype: int64

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %%
from imblearn import under_sampling,over_sampling
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# %%
ros = RandomOverSampler(random_state = 0)
a_re ,b_re = ros.fit_resample(x,y)
print(sorted(Counter(b_re).items()),b_re.shape)
# Out:
# [(0, 27932), (1, 27932)] (55864,)

# %%
ros = RandomUnderSampler(random_state = 0)
x_re ,y_re = ros.fit_resample(x,y)
print(sorted(Counter(y_re).items()),y_re.shape)
# Out:
# [(0, 3715), (1, 3715)] (7430,)

# %%
y.value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='subscribed'>

# %%
df['subscribed'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='subscribed'>

# %%
x=x_re
y=y_re

# %%
x.describe()
# Out:
#                age          job      marital    education      default  \
# count  7430.000000  7430.000000  7430.000000  7430.000000  7430.000000
# mean     41.168102     4.302153     0.748856     1.563526     0.014670
# std      11.840524     2.692293     0.906696     0.778939     0.120237
# min      18.000000     0.000000     0.000000     0.000000     0.000000
# 25%      32.000000     3.000000     0.000000     1.000000     0.000000
# 50%      39.000000     4.000000     0.000000     1.000000     0.000000
# 75%      49.000000     6.000000     2.000000     2.000000     0.000000
# max      95.000000    11.000000     2.000000     3.000000     1.000000
#
#             balance      housing         loan      contact          day  \
# count   7430.000000  7430.000000  7430.000000  7430.000000  7430.000000
# mean    1532.923822     0.470794     0.132301     1.142530    15.568237
# std     3205.819736     0.499180     0.338841     0.509442     8.453024
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x)

x_sca = scaler.transform(x)
x_sca= pd.DataFrame(x_sca, columns=x.columns)

# %%
x_sca.describe()
# Out:
#                 age           job       marital     education       default  \
# count  7.430000e+03  7.430000e+03  7.430000e+03  7.430000e+03  7.430000e+03
# mean  -1.912632e-16  1.114108e-16 -7.650527e-18 -7.411448e-17  2.868948e-17
# std    1.000067e+00  1.000067e+00  1.000067e+00  1.000067e+00  1.000067e+00
# min   -1.956810e+00 -1.598059e+00 -8.259728e-01 -2.007386e+00 -1.220192e-01
# 25%   -7.743508e-01 -4.836922e-01 -8.259728e-01 -7.235023e-01 -1.220192e-01
# 50%   -1.831210e-01 -1.122366e-01 -8.259728e-01 -7.235023e-01 -1.220192e-01
# 75%    6.614931e-01  6.306747e-01  1.379986e+00  5.603817e-01 -1.220192e-01
# max    4.546718e+00  2.487953e+00  1.379986e+00  1.844266e+00  8.195434e+00
#
#             balance       housing          loan       contact           day  \
# count  7.430000e+03  7.430000e+03  7.430000e+03  7.430000e+03  7.430000e+03
# mean  -3.825264e-17  1.224084e-16  2.295158e-17  9.180633e-17  1.530105e-17
# ...

# %%
x.plot(kind='box',figsize=(30,25))
# Out:
# <Axes: >

# %%
x_sca.plot(kind='box',figsize=(30,25))
# Out:
# <Axes: >

# %%
aaa
# Out:
# 'duration,pdays,poutcome,previous,housing,contact'

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %%
df2 = pd.read_csv('termdeposit_test.csv')
df2
# Out:
#           ID  age            job   marital  education default  balance  \
# 0      38441   32       services   married  secondary      no      118
# 1      40403   78        retired  divorced    primary      no     2787
# 2       3709   31  self-employed    single   tertiary      no      144
# 3      37422   57       services    single    primary      no     3777
# 4      12527   45    blue-collar  divorced  secondary      no     -705
# ...      ...  ...            ...       ...        ...     ...      ...
# 13559  23465   39     management   married   tertiary      no       45
# 13560  11743   54    blue-collar   married    primary      no     2281
# 13561  28292   35        retired   married    primary      no      285
# 13562  45163   29         admin.    single  secondary      no      464
# 13563  34839   29         admin.   married  secondary      no        2
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %% [markdown]
# #  Target column is not present in termdeposit_test.csv

# %%
del df2['ID']

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13564 entries, 0 to 13563
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        13564 non-null  int64
#  1   job        13564 non-null  object
#  2   marital    13564 non-null  object
#  3   education  13564 non-null  object
#  4   default    13564 non-null  object
#  5   balance    13564 non-null  int64
#  6   housing    13564 non-null  object
#  7   loan       13564 non-null  object
#  8   contact    13564 non-null  object
#  9   day        13564 non-null  int64
#  10  month      13564 non-null  object
#  11  duration   13564 non-null  int64
#  12  campaign   13564 non-null  int64
#  13  pdays      13564 non-null  int64
#  14  previous   13564 non-null  int64
#  15  poutcome   13564 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 1.7+ MB

# %%
df2.nunique()
# Out:
# age            75
# job            12
# marital         3
# education       4
# default         2
# balance      4292
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1201
# campaign       40
# pdays         422
# previous       33
# poutcome        4
# dtype: int64

# %%
df['job'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='job'>

# %%
df2['job'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='job'>

# %%
df['marital'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='marital'>

# %%
df2['marital'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='marital'>

# %%
df['education'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='education'>

# %%
df2['education'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='education'>

# %%
df['default'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='default'>

# %%
df2['default'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='default'>

# %%
df['housing'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='housing'>

# %%
df2['housing'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='housing'>

# %%
df['loan'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='loan'>

# %%
df2['loan'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='loan'>

# %%
df['contact'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='contact'>

# %%
df2['contact'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='contact'>

# %%
df['month'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='month'>

# %%
df2['month'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='month'>

# %%
df['subscribed'].value_counts().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: ylabel='subscribed'>

# %%
df2['job'].value_counts()
# Out:
# blue-collar      2890
# management       2819
# technician       2290
# admin.           1540
# services         1251
# retired           690
# entrepreneur      479
# self-employed     456
# unemployed        398
# housemaid         366
# student           303
# unknown            82
# Name: job, dtype: int64

# %%
df2['job']= pd.factorize(df2['job'])[0]

# %%
df2['job'].value_counts()
# Out:
# 3     2890
# 4     2819
# 5     2290
# 6     1540
# 0     1251
# 1      690
# 9      479
# 2      456
# 7      398
# 8      366
# 10     303
# 11      82
# Name: job, dtype: int64

# %%
df2['marital'].value_counts()
# Out:
# married     8119
# single      3868
# divorced    1577
# Name: marital, dtype: int64

# %%
df2['marital']= pd.factorize(df2['marital'])[0]

# %%
df2['marital'].value_counts()
# Out:
# 0    8119
# 2    3868
# 1    1577
# Name: marital, dtype: int64

# %%
df2['education'].value_counts()
# Out:
# secondary    6978
# tertiary     4000
# primary      2043
# unknown       543
# Name: education, dtype: int64

# %%
df2['education']= pd.factorize(df2['education'])[0]

# %%
df2['education'].value_counts()
# Out:
# 0    6978
# 2    4000
# 1    2043
# 3     543
# Name: education, dtype: int64

# %%
df2['default'].value_counts()
# Out:
# no     13334
# yes      230
# Name: default, dtype: int64

# %%
df2['default']= pd.factorize(df2['default'])[0]

# %%
df2['default'].value_counts()
# Out:
# 0    13334
# 1      230
# Name: default, dtype: int64

# %%
df2['housing'].value_counts()
# Out:
# yes    7546
# no     6018
# Name: housing, dtype: int64

# %%
df2['housing']= pd.factorize(df2['housing'])[0]

# %%
df2['housing'].value_counts()
# Out:
# 0    7546
# 1    6018
# Name: housing, dtype: int64

# %%
df2['loan'].value_counts()
# Out:
# no     11451
# yes     2113
# Name: loan, dtype: int64

# %%
df2['loan']= pd.factorize(df2['loan'])[0]

# %%
df2['loan'].value_counts()
# Out:
# 0    11451
# 1     2113
# Name: loan, dtype: int64

# %%
df2['contact'].value_counts()
# Out:
# cellular     8862
# unknown      3843
# telephone     859
# Name: contact, dtype: int64

# %%
df2['contact']= pd.factorize(df2['contact'])[0]

# %%
df2['contact'].value_counts()
# Out:
# 0    8862
# 2    3843
# 1     859
# Name: contact, dtype: int64

# %%
df2['month'].value_counts()
# Out:
# may    4097
# jul    2051
# aug    1914
# jun    1603
# nov    1187
# apr     877
# feb     822
# jan     426
# oct     226
# sep     169
# mar     135
# dec      57
# Name: month, dtype: int64

# %%
df2['month']= pd.factorize(df2['month'])[0]

# %%
df2['month'].value_counts()
# Out:
# 0     4097
# 1     2051
# 6     1914
# 2     1603
# 10    1187
# 9      877
# 4      822
# 8      426
# 11     226
# 5      169
# 3      135
# 7       57
# Name: month, dtype: int64

# %%
df2['poutcome'].value_counts()
# Out:
# unknown    11030
# failure     1539
# other        552
# success      443
# Name: poutcome, dtype: int64

# %%
df2['poutcome']= pd.factorize(df2['poutcome'])[0]

# %%
df2['poutcome'].value_counts()
# Out:
# 0    11030
# 1     1539
# 2      552
# 3      443
# Name: poutcome, dtype: int64

# %% [markdown]
# .

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df2.corr(), fmt='.1g', annot=True, annot_kws={'fontsize':12})
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,10))
sns.heatmap(x_sca.corr(), fmt='.1g', annot=True, annot_kws={'fontsize':12})
# Out:
# <Axes: >

# %% [markdown]
# # test csv is more or less the same as train csv

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %%
from sklearn.ensemble import GradientBoostingClassifier , AdaBoostClassifier , BaggingClassifier , RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_sca,y, test_size=0.3, random_state=42)

# %%
x_train_sca= x_train
x_test_sca= x_test

# %%
x_train_sca.shape
# Out:
# (5201, 16)

# %%
x_test_sca.shape
# Out:
# (2229, 16)

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # Classification_report

# %%
abc =AdaBoostClassifier()
abc.fit(x_train_sca,y_train)
abcy_pred = abc.predict(x_test_sca)

print(accuracy_score(y_test,abcy_pred))
print(classification_report(y_test,abcy_pred))
# Out:
# 0.82907133243607
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      1106
#            1       0.84      0.82      0.83      1123
#
#     accuracy                           0.83      2229
#    macro avg       0.83      0.83      0.83      2229
# weighted avg       0.83      0.83      0.83      2229

# %%
gbc = GradientBoostingClassifier()
gbc.fit(x_train_sca,y_train)
gbcy_pred = gbc.predict(x_test_sca)

print(accuracy_score(y_test,gbcy_pred))
print(classification_report(y_test,gbcy_pred))
# Out:
# 0.8555406011664424
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1106
#            1       0.84      0.89      0.86      1123
#
#     accuracy                           0.86      2229
#    macro avg       0.86      0.86      0.86      2229
# weighted avg       0.86      0.86      0.86      2229

# %%
gs = GaussianNB()
gs.fit(x_train_sca,y_train)
gsy_pred = gs.predict(x_test_sca)

print(accuracy_score(y_test,gsy_pred))
print(classification_report(y_test,gsy_pred))
# Out:
# 0.7550471063257066
#               precision    recall  f1-score   support
#
#            0       0.78      0.71      0.74      1106
#            1       0.74      0.80      0.77      1123
#
#     accuracy                           0.76      2229
#    macro avg       0.76      0.75      0.75      2229
# weighted avg       0.76      0.76      0.75      2229

# %%
rfc= RandomForestClassifier()
rfc.fit(x_train_sca,y_train)
rfcy_pred = rfc.predict(x_test_sca)

print(accuracy_score(y_test,rfcy_pred))
print(classification_report(y_test,rfcy_pred))
# Out:
# 0.8591296545536115
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1106
#            1       0.84      0.89      0.86      1123
#
#     accuracy                           0.86      2229
#    macro avg       0.86      0.86      0.86      2229
# weighted avg       0.86      0.86      0.86      2229

# %%
bc = BaggingClassifier()
bc.fit(x_train_sca,y_train)
bcy_pred = bc.predict(x_test_sca)

print(accuracy_score(y_test,bcy_pred))
print(classification_report(y_test,bcy_pred))
# Out:
# 0.8250336473755047
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82      1106
#            1       0.83      0.82      0.83      1123
#
#     accuracy                           0.83      2229
#    macro avg       0.83      0.83      0.83      2229
# weighted avg       0.83      0.83      0.83      2229

# %%
lr = LogisticRegression()
lr.fit(x_train_sca,y_train)
lry_pred = lr.predict(x_test_sca)

print(classification_report(y_test,lry_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79      1106
#            1       0.80      0.79      0.79      1123
#
#     accuracy                           0.79      2229
#    macro avg       0.79      0.79      0.79      2229
# weighted avg       0.79      0.79      0.79      2229

# %%
dtc= DecisionTreeClassifier()
dtc.fit(x_train_sca,y_train)
dtcy_pred = dtc.predict(x_test_sca)

print(accuracy_score(y_test,dtcy_pred))
print(classification_report(y_test,dtcy_pred))
# Out:
# 0.7913862718707941
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79      1106
#            1       0.79      0.81      0.80      1123
#
#     accuracy                           0.79      2229
#    macro avg       0.79      0.79      0.79      2229
# weighted avg       0.79      0.79      0.79      2229

# %%
model= SVC()
model.fit(x_train_sca,y_train)
modely_pred = model.predict(x_test_sca)
print(accuracy_score(y_test,modely_pred))
print(classification_report(y_test,modely_pred))
# Out:
# 0.8232391206819202
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82      1106
#            1       0.81      0.84      0.83      1123
#
#     accuracy                           0.82      2229
#    macro avg       0.82      0.82      0.82      2229
# weighted avg       0.82      0.82      0.82      2229

# %%
accuracy = pd.DataFrame([
    [1,'GradientBoostingClassifier','85%'],
    [2,'RandomForestClassifier','86%'],
    [3,'AdaBoostClassifier','82%'],
    [4,'LogisticRegression','80%'],
    [5,'GaussianNB','75%'],
    [6,'DecisionTreeClassifier','80%'],
    [7,'svc','82%'],
    [8,'BaggingClassifier','84%']
],columns=['id','Models','scaled_Accuracy_before_cross_val'])

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # Cross_Value_Score

# %%
from sklearn.model_selection import cross_val_score

# %%
recheck = cross_val_score(gbc,x,y)
print(recheck)
print(recheck.mean())
print("difference",accuracy_score(y_test,gbcy_pred) - recheck.mean())
# Out:
# [0.84522207 0.84858681 0.84522207 0.84858681 0.86271871]
# 0.8500672947510095
# difference 0.005473306415432866

# %%
recheck = cross_val_score(rfc,x,y)
print(recheck)
print(recheck.mean())
print("difference",accuracy_score(y_test,rfcy_pred) - recheck.mean())
# Out:
# [0.85531629 0.85800808 0.8512786  0.85935397 0.86271871]
# 0.8573351278600269
# difference 0.0017945266935845972

# %%
recheck = cross_val_score(abc,x,y)
print(recheck)
print(recheck.mean())
print("difference",accuracy_score(y_test,abcy_pred) - recheck.mean())
# Out:
# [0.83243607 0.83445491 0.83781965 0.82503365 0.83983849]
# 0.8339165545087484
# difference -0.004845222072678346

# %%
recheck = cross_val_score(lr,x,y)
print(recheck)
print(recheck.mean())
print("difference",accuracy_score(y_test,lry_pred) - recheck.mean())
# Out:
# [0.78869448 0.76312248 0.75908479 0.78734859 0.77860027]
# 0.7753701211305517
# difference 0.016913414087034617

# %%
recheck = cross_val_score(gs,x,y)
print(recheck)
print(recheck.mean())
print("difference",accuracy_score(y_test,gsy_pred) - recheck.mean())
# Out:
# [0.77321669 0.77523553 0.76177658 0.74562584 0.78734859]
# 0.7686406460296096
# difference -0.01359353970390298

# %%
recheck = cross_val_score(dtc,x,y)
print(recheck)
print(recheck.mean())
print("difference",accuracy_score(y_test,dtcy_pred) - recheck.mean())
# Out:
# [0.78263795 0.78734859 0.77321669 0.79273217 0.80686406]
# 0.7885598923283983
# difference 0.0028263795423958404

# %%
recheck = cross_val_score(model,x,y)
print(recheck)
print(recheck.mean())
print("difference",accuracy_score(y_test,modely_pred) - recheck.mean())
# Out:
# [0.72880215 0.73553163 0.71130552 0.74293405 0.72880215]
# 0.7294751009421265
# difference 0.09376401973979365

# %%
recheck = cross_val_score(bc,x,y)
print(recheck)
print(recheck.mean())
print("difference",accuracy_score(y_test,bcy_pred) - recheck.mean())
# Out:
# [0.82099596 0.84454913 0.83378197 0.82705249 0.82907133]
# 0.8310901749663525
# difference -0.006056527590847849

# %% [markdown]
# .

# %% [markdown]
# .

# %%
cross_value= pd.DataFrame([
    [1,'GradientBoostingClassifier','85%'],
    [2,'RandomForestClassifier','85%'],
    [3,'AdaBoostClassifier','83%'],
    [4,'LogisticRegression','77%'],
    [5,'GaussianNB','76%'],
    [6,'DecisionTreeClassifier','78%'],
    [7,'svc','72%'],
    [8,'BaggingClassifier','83%']
],columns=['id','Models','over_sampled_Accuracy'])

# %%
cross_value.merge(accuracy)
# Out:
#    id                      Models over_sampled_Accuracy  \
# 0   1  GradientBoostingClassifier                   85%
# 1   2      RandomForestClassifier                   85%
# 2   3          AdaBoostClassifier                   83%
# 3   4          LogisticRegression                   77%
# 4   5                  GaussianNB                   76%
# 5   6      DecisionTreeClassifier                   78%
# 6   7                         svc                   72%
# 7   8           BaggingClassifier                   83%
#
#   scaled_Accuracy_before_cross_val
# 0                              85%
# 1                              86%
# 2                              82%
# 3                              80%
# 4                              75%
# 5                              80%
# 6                              82%
# 7                              84%

# %% [markdown]
# .

# %% [raw]
# import pickle
# pickle.dump(gbc,open('Termdeposit.sav','wb'))

# %% [raw]
# import pickle
# load_model = pickle.load(open('Termdeposit.sav','rb'))

# %%
import pickle
with open('Termdeposit.pkl','wb')as file:
    pickle.dump(gbc,file)

# %%
import pickle
with open('Termdeposit.pkl','rb')as file:
    Termdeposit=pickle.load(file)
Termdeposit
# Out:
# GradientBoostingClassifier()

# %%
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       56    0        0          0        0     1933        0     0        0
# 1       31    1        0          1        0        3        0     0        1
# 2       27    2        0          1        0      891        1     0        1
# 3       57    3        1          2        0     3287        0     0        1
# 4       31    4        0          1        0      119        1     0        1
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 31642   29    3        2          2        0        0        1     0        1
# 31643   53    3        1          2        0      380        0     1        1
# 31644   32    3        2          2        0      312        0     0        1
# 31645   57    4        0          1        0      225        1     0        0
# 31646   55    3        1          1        0      204        1     0        1
#
# ...

# %%
beta = gbc.predict(x_test)

# %%
gama = pd.DataFrame(beta)

# %%
theta=pd.DataFrame(y_test)

# %%
y_test.value_counts()
# Out:
# 1    1123
# 0    1106
# Name: subscribed, dtype: int64

# %%
gama.value_counts()
# Out:
# 1    1189
# 0    1040
# dtype: int64

# %%
gama.columns = ['predi']

# %%
gama['id'] = np.arange(len(gama))

# %%
theta['id'] = np.arange(len(theta))

# %%
compare = theta.merge(gama)

# %%
compare.head(50)
# Out:
#     subscribed  id  predi
# 0            0   0      0
# 1            0   1      0
# 2            0   2      1
# 3            1   3      0
# 4            0   4      0
# 5            1   5      1
# 6            1   6      1
# 7            1   7      1
# 8            0   8      0
# 9            0   9      0
# 10           1  10      1
# 11           0  11      0
# 12           1  12      1
# 13           1  13      1
# 14           0  14      0
# 15           0  15      0
# 16           0  16      0
# 17           0  17      0
# 18           0  18      0
# 19           1  19      1
# 20           0  20      0
# 21           0  21      1
# 22           0  22      0
# 23           1  23      1
# 24           0  24      0
# 25           1  25      1
# 26           1  26      1
# 27           0  27      0
# 28           0  28      0
# 29           1  29      1
# 30           0  30      1
# 31           0  31      1
# 32           1  32      1
# 33           1  33      1
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %%
ANSWER = gbc.predict(df2)

# %%
ANSWER = pd.DataFrame(ANSWER)

# %%
ANSWER.value_counts()
# Out:
# 1    13526
# 0       38
# dtype: int64
