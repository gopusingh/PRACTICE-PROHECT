# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
df=df.drop('Seat No.',axis=1)

# %%
x=df.iloc[:,:41]

# %%
x
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
y=df['CGPA']

# %%
y.value_counts()
# Out:
# 3.019    5
# 3.058    3
# 2.793    3
# 3.443    3
# 2.206    3
#         ..
# 2.555    1
# 2.042    1
# 2.634    1
# 2.053    1
# 1.753    1
# Name: CGPA, Length: 491, dtype: int64

# %%
x.iloc[:,:1].nunique()
# Out:
# PH-121    13
# dtype: int64

# %%
aa=x['PH-121'].unique()

# %%
aa=pd.DataFrame(aa)

# %%
aa
# Out:
#      0
# 0   B-
# 1    A
# 2    D
# 3   A-
# 4   B+
# 5    B
# 6   C+
# 7    C
# 8   C-
# 9   D+
# 10  WU
# 11  A+
# 12   F

# %%
grades = {
    'A+':1,
    'A':2,
    'A-':3,
    'B+':4,
    'B':5,
    'B-':6,
    'C+':7,
    'C':8,
    'C-':9,
    'D+':10,
    'D':11,
    'F':12,
    'WU':13
}

# %% [raw]
# grades = {
#     'A+':1.1,
#     'A':1.2,
#     'A-':1.3,
#     'B+':1.4,
#     'B':1.5,
#     'B-':1.6,
#     'C+':1.7,
#     'C':1.8,
#     'C-':1.9,
#     'D+':2.1,
#     'D':2.2,
#     'F':2.3,
#     'WU':2.4
# }

# %% [raw]
# x['PH-121']=x['PH-121'].map(grades)

# %% [raw]
# x=x.apply(lambda a:pd.factorize(a)[0])

# %%
x = x.apply(lambda a:a.map(grades))

# %%
x
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         6      10     9.0        8.0     9.0      10    11.0     9.0
# 1         2      11    10.0       11.0     6.0       8    11.0     2.0
# 2         2       5     2.0        6.0     4.0       2     6.0     4.0
# 3        11       7    10.0       11.0    11.0       3    10.0     9.0
# 4         3       3     3.0        4.0     2.0       2     3.0     4.0
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       5       2     2.0        3.0     1.0       2     3.0     3.0
# 567       1       2     2.0        2.0     2.0       2     2.0     3.0
# 568       5       2     3.0        4.0     2.0       2     2.0     2.0
# 569       2       4    11.0        2.0    11.0      10     6.0     9.0
# 570       8      11    11.0        8.0     8.0      10     5.0     7.0
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %% [markdown]
# x.merge(y)

# %%
CGPA = df['CGPA']

# %%
x['CGPA'] = CGPA

# %%
x
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         6      10     9.0        8.0     9.0      10    11.0     9.0
# 1         2      11    10.0       11.0     6.0       8    11.0     2.0
# 2         2       5     2.0        6.0     4.0       2     6.0     4.0
# 3        11       7    10.0       11.0    11.0       3    10.0     9.0
# 4         3       3     3.0        4.0     2.0       2     3.0     4.0
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       5       2     2.0        3.0     1.0       2     3.0     3.0
# 567       1       2     2.0        2.0     2.0       2     2.0     3.0
# 568       5       2     3.0        4.0     2.0       2     2.0     2.0
# 569       2       4    11.0        2.0    11.0      10     6.0     9.0
# 570       8      11    11.0        8.0     8.0      10     5.0     7.0
#
#      EE-119  ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
x.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  570.000000  570.000000  569.000000  571.000000
# mean     4.971979    6.190893    4.191228    5.357895    5.029877    4.005254
# std      2.947360    2.724223    2.809148    3.107050    2.844717    2.500872
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000    4.000000    2.000000    3.000000    3.000000    2.000000
# 50%      4.000000    6.000000    3.000000    5.000000    4.000000    3.000000
# 75%      7.000000    8.000000    5.750000    8.000000    7.000000    5.000000
# max     13.000000   12.000000   13.000000   13.000000   13.000000   11.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      CS-312  \
# count  569.000000  569.000000  569.000000  569.000000  ...  560.000000
# mean     5.163445    5.077329    4.984183    5.933216  ...    5.050000
# ...

# %%
x.plot(kind='box',figsize=(30,25))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(40,30))
sns.heatmap(x.corr(),annot=True,fmt='.1g',annot_kws={'fontsize':15})
# Out:
# <Axes: >

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    int64
#  1   HS-101     571 non-null    int64
#  2   CY-105     570 non-null    float64
#  3   HS-105/12  570 non-null    float64
#  4   MT-111     569 non-null    float64
#  5   CS-105     571 non-null    int64
#  6   CS-106     569 non-null    float64
#  7   EL-102     569 non-null    float64
#  8   EE-119     569 non-null    float64
#  9   ME-107     569 non-null    float64
#  10  CS-107     568 non-null    float64
#  11  HS-205/20  566 non-null    float64
#  12  MT-222     565 non-null    float64
#  13  EE-222     562 non-null    float64
#  14  MT-224     563 non-null    float64
#  15  CS-210     563 non-null    float64
#  16  CS-211     565 non-null    float64
#  17  CS-203     565 non-null    float64
#  18  CS-214     564 non-null    float64
# ...

# %%
x.isnull().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        3
# HS-205/20     5
# MT-222        6
# EE-222        9
# MT-224        8
# CS-210        8
# CS-211        6
# CS-203        6
# CS-214        7
# EE-217        6
# CS-212        6
# CS-215        7
# MT-331        9
# EF-303       10
# HS-304       12
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318       10
# CS-306        9
# CS-312       11
# CS-317       12
# CS-403       12
# CS-421       14
# CS-406       88
# CS-414       15
# CS-419       13
# CS-423       14
# CS-412       82
# CGPA          0
# dtype: int64

# %%
x.loc[x['CY-105']==" "]
x['CY-105'] = x['CY-105'].replace(" ",np.nan)
x['CY-105'] = x['CY-105'].fillna(x['CY-105'].mean())
x['CY-105']=x['CY-105'].astype('int')

# %%
x.loc[x['HS-101']==" "]
x['HS-101'] = x['HS-101'].replace(" ",np.nan)
x['HS-101'] = x['HS-101'].fillna(x['HS-101'].mean())
x['HS-101']=x['HS-101'].astype('int')

# %%
x = x.apply(lambda a:a.replace(" ",np.nan))

# %%
x = x.apply(lambda a:a.fillna(a.mean()))

# %%
x = x.apply(lambda a:a.astype('int'))

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    int32
#  1   HS-101     571 non-null    int32
#  2   CY-105     571 non-null    int32
#  3   HS-105/12  571 non-null    int32
#  4   MT-111     571 non-null    int32
#  5   CS-105     571 non-null    int32
#  6   CS-106     571 non-null    int32
#  7   EL-102     571 non-null    int32
#  8   EE-119     571 non-null    int32
#  9   ME-107     571 non-null    int32
#  10  CS-107     571 non-null    int32
#  11  HS-205/20  571 non-null    int32
#  12  MT-222     571 non-null    int32
#  13  EE-222     571 non-null    int32
#  14  MT-224     571 non-null    int32
#  15  CS-210     571 non-null    int32
#  16  CS-211     571 non-null    int32
#  17  CS-203     571 non-null    int32
#  18  CS-214     571 non-null    int32
#  19  EE-217     571 non-null    int32
# ...

# %%
sns.boxplot(x['CGPA'])
# Out:
# <Axes: >

# %%
x.skew()
# Out:
# PH-121       0.762314
# HS-101       0.172287
# CY-105       1.231647
# HS-105/12    0.455980
# MT-111       0.662598
# CS-105       1.117788
# CS-106       0.870833
# EL-102       0.674342
# EE-119       0.723684
# ME-107       0.290464
# CS-107       0.497336
# HS-205/20    1.267401
# MT-222       0.287964
# EE-222       0.916814
# MT-224       0.567634
# CS-210       0.929023
# CS-211       0.173682
# CS-203       0.404896
# CS-214       0.031499
# EE-217       0.882296
# CS-212       0.557961
# CS-215       0.246319
# MT-331       0.760734
# EF-303       0.256005
# HS-304       0.581548
# CS-301       0.562351
# CS-302       0.899915
# TC-383       0.414526
# MT-442       1.088061
# EL-332       0.568171
# CS-318       0.413668
# CS-306       0.649468
# CS-312       0.335422
# CS-317       0.211884
# CS-403       0.716374
# CS-421       0.203067
# CS-406       1.648723
# CS-414       1.647618
# CS-419       0.715658
# CS-423       0.693998
# CS-412       1.558579
# ...

# %% [markdown]
# .

# %% [markdown]
# .

# %%
df
# Out:
#     PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119 ME-107  \
# 0       B-     D+     C-         C     C-     D+      D     C-     B-     C-
# 1        A      D     D+         D     B-      C      D      A     D+      D
# 2        A      B      A        B-     B+      A     B-     B+     A-     A-
# 3        D     C+     D+         D      D     A-     D+     C-      D     C+
# 4       A-     A-     A-        B+      A      A     A-     B+      A     A-
# ..     ...    ...    ...       ...    ...    ...    ...    ...    ...    ...
# 566      B      A      A        A-     A+      A     A-     A-     A+     B+
# 567     A+      A      A         A      A      A      A     A-      A      A
# 568      B      A     A-        B+      A      A      A      A      A      B
# 569      A     B+      D         A      D     D+     B-     C-     B-     C-
# 570      C      D      D         C      C     D+      B     C+      C     D+
#
# ...

# %%
x
# Out:
#      PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  \
# 0         6      10       9          8       9      10      11       9
# 1         2      11      10         11       6       8      11       2
# 2         2       5       2          6       4       2       6       4
# 3        11       7      10         11      11       3      10       9
# 4         3       3       3          4       2       2       3       4
# ..      ...     ...     ...        ...     ...     ...     ...     ...
# 566       5       2       2          3       1       2       3       3
# 567       1       2       2          2       2       2       2       3
# 568       5       2       3          4       2       2       2       2
# 569       2       4      11          2      11      10       6       9
# 570       8      11      11          8       8      10       5       7
#
#      EE-119  ME-107  ...  CS-306  CS-312  CS-317  CS-403  CS-421  CS-406  \
# ...

# %%
y
# Out:
# 0      2.205
# 1      2.008
# 2      3.608
# 3      1.906
# 4      3.448
#        ...
# 566    3.798
# 567    3.772
# 568    3.470
# 569    2.193
# 570    1.753
# Name: CGPA, Length: 571, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %%
x_train.shape
# Out:
# (399, 41)

# %%
x_test.shape
# Out:
# (172, 41)

# %% [markdown]
# .

# %% [markdown]
# .

# %%
svm = SVR()
svm.fit(x_train,y_train)
# Out:
# SVR()

# %%
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
rfr= RandomForestRegressor()
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
gbr= GradientBoostingRegressor()
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred1 = svm.predict(x_test)
y_pred2 = lr.predict(x_test)
y_pred3 = rfr.predict(x_test)
y_pred4 = gbr.predict(x_test)

# %% [markdown]
# .

# %% [markdown]
# .

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score , confusion_matrix

# %%
svm1 = metrics.r2_score(y_test,y_pred1)
svm1
# Out:
# 0.956301847081658

# %%
lr2 = metrics.r2_score(y_test,y_pred2)
lr2
# Out:
# 0.9716291458275303

# %%
rfr3 = metrics.r2_score(y_test,y_pred3)
rfr3
# Out:
# 0.96137919557568

# %%
gbr4 = metrics.r2_score(y_test,y_pred4)
gbr4
# Out:
# 0.9600537499708073

# %% [markdown]
# .

# %% [markdown]
# .

# %%
from sklearn.model_selection import cross_val_score

# %%
recheck = cross_val_score(svm,x,y)
print(recheck)
print(recheck.mean())
# Out:
# [0.91805174 0.9601603  0.93230018 0.96417262 0.89074296]
# 0.9330855600999863

# %%
recheck = cross_val_score(lr,x,y)
print(recheck)
print(recheck.mean())
# Out:
# [0.92970123 0.95220636 0.9316498  0.97439194 0.90235699]
# 0.938061266545216

# %%
recheck = cross_val_score(rfr,x,y)
print(recheck)
print(recheck.mean())
# Out:
# [0.90475183 0.95126261 0.94548468 0.95194232 0.86082664]
# 0.9228536144410153

# %%
recheck = cross_val_score(gbr,x,y)
print(recheck)
print(recheck.mean())
# Out:
# [0.93233184 0.95871635 0.95210456 0.96517679 0.88455616]
# 0.9385771398331102

# %% [markdown]
# .

# %% [markdown]
# .

# %%
import pickle
with open('Grades.pkl','wb')as file:
    pickle.dump(lr,file)

# %%
import pickle
with open('Grades.pkl','rb')as file:
    Grades=pickle.load(file)
Grades
# Out:
# LinearRegression()

# %%
xpredi = lr.predict(x_test)
xpredi = pd.DataFrame(predi)
xpredi.columns = ['predi']

# %%
theta=pd.DataFrame(y_test)

# %%
xpredi['id'] = np.arange(len(xpredi))
theta['id'] = np.arange(len(theta))

# %%
compare = theta.merge(xpredi)
compare=compare.set_index('id')
compare.head(50)
# Out:
#      CGPA     predi
# id
# 0   1.992  2.097753
# 1   3.490  3.453338
# 2   2.823  2.826277
# 3   2.288  2.312034
# 4   3.816  3.805557
# 5   3.476  3.569641
# 6   2.634  2.522179
# 7   2.294  2.231569
# 8   2.171  2.117103
# 9   3.060  3.024616
# 10  3.481  3.583730
# 11  2.860  2.753513
# 12  3.679  3.720420
# 13  2.611  2.477679
# 14  3.876  3.939894
# 15  2.763  2.706429
# 16  2.206  2.203286
# 17  3.625  3.667504
# 18  1.768  1.419461
# 19  2.408  2.459053
# 20  2.340  2.568486
# 21  3.856  3.837349
# 22  2.193  2.082558
# 23  2.484  2.441311
# 24  2.925  2.874430
# 25  3.378  3.318462
# 26  3.271  3.233716
# 27  2.429  2.509109
# 28  3.353  3.359197
# 29  3.458  3.450654
# 30  2.654  2.967633
# 31  2.776  2.708987
# 32  3.477  3.458157
# 33  3.369  3.362248
# 34  3.754  3.849869
# 35  3.010  2.985914
# 36  2.681  2.647542
# 37  3.882  3.915216
# 38  2.957  3.038753
# 39  2.084  1.787675
# 40  3.758  3.738678
# 41  3.451  3.493582
# 42  3.721  3.697045
# 43  3.705  3.706159
# ...
